# %%
# dependencies
import pandas as pd
import os
my_dir = os.path.dirname(os.path.abspath('__file__'))
os.chdir(my_dir)

# %%
pdx_hpi_by_zip = 'data/cleaned data/pdx_hpi_by_zip.csv'
pdx_hpi_by_zip_df = pd.read_csv(pdx_hpi_by_zip)

PDX_Crime_zip_year = 'data/cleaned data/PDX_Crime_zip_year.csv'
PDX_Crime_zip_year_df = pd.read_csv(PDX_Crime_zip_year)

# %%
merged_df = pdx_hpi_by_zip_df.merge(PDX_Crime_zip_year_df, 
                                left_on=['Five-Digit ZIP Code', 'Year'],
                                right_on=['zip', 'year'],
                                how='left')

# %%
merged_df
# Out:
#       Five-Digit ZIP Code  Year Annual Change (%)      HPI  HPI from 2012
# 0                   97201  1986                 .   100.00         397.73  \
# 1                   97201  1987              5.95   105.95         397.73
# 2                   97201  1988              5.41   111.68         397.73
# 3                   97201  1989              9.27   122.03         397.73
# 4                   97201  1990             14.09   139.23         397.73
# ...                   ...   ...               ...      ...            ...
# 1520                97267  2018               5.2   939.69         545.32
# 1521                97267  2019              3.22   969.90         545.32
# 1522                97267  2020              3.42  1003.08         545.32
# 1523                97267  2021             13.21  1135.53         545.32
# 1524                97267  2022              13.6  1289.94         545.32
#
#       HPI with 2012 base  normalized_sale_price  zip_code
# 0               0.251427            86369.11715     97201  \
# 1               0.266387            91508.07962     97201
# 2               0.280794            96457.03003     97201
# 3               0.306816           105396.23370     97201
# 4               0.350062           120251.72180     97201
# ...                  ...                    ...       ...
# 1520            1.723190           388793.00000     97267
# 1521            1.778589           398146.00000     97267
# 1522            1.839434           433363.00000     97267
# 1523            2.082319           503429.00000     97267
# 1524            2.365473           539303.00000     97267
#
#       normalized_sale_price_2012 Neighborhood  year  Person  Property
# 0                    343515.8896          NaN   NaN     NaN       NaN  \
# 1                    343515.8896          NaN   NaN     NaN       NaN
# 2                    343515.8896          NaN   NaN     NaN       NaN
# 3                    343515.8896          NaN   NaN     NaN       NaN
# 4                    343515.8896          NaN   NaN     NaN       NaN
# ...                          ...          ...   ...     ...       ...
# 1520                 218443.3423          NaN   NaN     NaN       NaN
# 1521                 218443.3423          NaN   NaN     NaN       NaN
# 1522                 218443.3423          NaN   NaN     NaN       NaN
# 1523                 218443.3423          NaN   NaN     NaN       NaN
# 1524                 218443.3423          NaN   NaN     NaN       NaN
#
#       Society  zip
# 0         NaN  NaN
# 1         NaN  NaN
# 2         NaN  NaN
# 3         NaN  NaN
# 4         NaN  NaN
# ...       ...  ...
# 1520      NaN  NaN
# 1521      NaN  NaN
# 1522      NaN  NaN
# 1523      NaN  NaN
# 1524      NaN  NaN
#
# [1525 rows x 15 columns]

# %%
columns_to_drop = ['zip_code', 'zip', 'year', 'Neighborhood', 'HPI from 2012', 'normalized_sale_price_2012']
final_df = merged_df.drop(columns=columns_to_drop)

# %%
local_data_agg_path = 'data/cleaned data/local_data_agg.csv'
final_df.to_csv(local_data_agg_path, index = False)
